# %%
import numpy as np
import sympy as sym
import json
from pydae.urisi.urisi_builder import urisi

import temp

# %%
model = temp.model()
params = {'p_c_A1':0.00001}  
# params = {
#     'p_load_A2_a':0.0e3,
#     'p_load_A2_b':0.0e3,
#     'p_load_A2_c':0.0e3,
#     'q_load_A2_a':0.0,
#     'q_load_A2_b':0.0,
#     'q_load_A2_c':0.0,
# }
model.ini(params,'xy_0.json')

# params = {
#     'p_load_A2_a':1.0e3,
#     'p_load_A2_b':1.0e3,
#     'p_load_A2_c':1.0e3,
#     'q_load_A2_a':0.0,
#     'q_load_A2_b':0.0,
#     'q_load_A2_c':0.0,
# }

# model.ini(params)

model.report_y()
model.report_z()
# Out:
# Maximum number of iterations (max_it = 50) reached without convergence.
# V_A1_0_r =  0.00
# V_A1_0_i =  0.00
# V_A1_1_r =  0.00
# V_A1_1_i =  0.00
# V_A1_2_r =  0.00
# V_A1_2_i =  0.00
# V_A1_3_r =  0.00
# V_A1_3_i =  0.00
# V_A2_0_r =  0.00
# V_A2_0_i =  0.00
# V_A2_1_r =  0.00
# V_A2_1_i =  0.00
# V_A2_2_r =  0.00
# V_A2_2_i =  0.00
# V_A2_3_r =  0.00
# V_A2_3_i =  0.00
# i_vsc_A1_a_r =  0.00
# i_vsc_A1_b_r =  0.00
# i_vsc_A1_c_r =  0.00
# i_vsc_A1_n_r =  0.00
# v_A1_o_r =  0.00
# i_vsc_A1_a_i =  0.00
# i_vsc_A1_b_i =  0.00
# i_vsc_A1_c_i =  0.00
# i_vsc_A1_n_i =  0.00
# v_A1_o_i =  0.00
# p_dc_A1 =  0.00
# omega_A1 =  0.00
# p_m_A1 =  0.00
# v_tao_r_A1 = 230.94
# v_tbo_r_A1 = -115.47
# v_tco_r_A1 = -115.47
# v_tao_i_A1 =  0.00
# v_tbo_i_A1 = -200.00
# v_tco_i_A1 = 200.00
# i_vsrc_A2_a_r =  0.00
# i_vsrc_A2_b_r =  0.00
# i_vsrc_A2_c_r =  0.00
# i_vsrc_A2_n_r =  0.00
# i_vsrc_A2_a_i =  0.00
# i_vsrc_A2_b_i =  0.00
# i_vsrc_A2_c_i =  0.00
# i_vsrc_A2_n_i =  0.00
# omega_coi =  0.00
# ...

# %%
model.report_u()
# Out:
# v_tao_r_A1 = 0.00
# v_tao_i_A1 = 0.00
# v_tbo_r_A1 = 0.00
# v_tbo_i_A1 =-0.00
# v_tco_r_A1 =-0.00
# v_tco_i_A1 =-0.00
# v_tno_r_A1 = 0.00
# v_tno_i_A1 = 0.00
# e_ao_m_A1 =230.94
# e_bo_m_A1 =230.94
# e_co_m_A1 =230.94
# e_no_m_A1 = 0.00
# v_ra_A1 = 0.00
# v_rb_A1 = 0.00
# v_rc_A1 = 0.00
# v_rn_A1 = 0.00
# phi_a_A1 = 0.00
# phi_b_A1 = 0.00
# phi_c_A1 = 0.00
# phi_n_A1 = 0.00
# p_c_A1 = 0.00
# omega_A1_ref = 1.00
# q_ref_A1 = 0.00
# e_ao_m_A2 =230.94
# e_bo_m_A2 =230.94
# e_co_m_A2 =230.94
# e_no_m_A2 = 0.00
# phi_A2 = 0.00
# u_freq = 0.00
