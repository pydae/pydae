# %%
import numpy as np
import matplotlib.pyplot as plt
import temp

from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
model=temp.model()
model.max_it = 1000

params = {'p_c_A1':0.1, 'K_delta_A1':1.0e2, 'K_qp_A1':0.0, 'K_qi_A1':0.0,
"e_ao_m_A1": 230.94*1.0,
"e_bo_m_A1": 230.94*1.0,
"e_co_m_A1": 230.94*1.0,
'i_dc_ref_A1':0.0, 'U_opt_A1':0.7
}  


model.ini(params,'xy_0.json')

model.ini({'K_delta_A1':0.0})
# Out:
# True

# %%
model.report_y()
# Out:
# V_A1_0_r = 230.99
# V_A1_0_i =  0.04
# V_A1_1_r = -115.46
# V_A1_1_i = -200.05
# V_A1_2_r = -115.52
# V_A1_2_i = 200.01
# V_A1_3_r = -0.01
# V_A1_3_i =  0.00
# V_A2_0_r = 230.94
# V_A2_0_i =  0.00
# V_A2_1_r = -115.47
# V_A2_1_i = -200.00
# V_A2_2_r = -115.47
# V_A2_2_i = 200.00
# V_A2_3_r =  0.00
# V_A2_3_i = -0.00
# i_vsrc_A2_a_r = -14.37
# i_vsrc_A2_b_r =  4.34
# i_vsrc_A2_c_r = 10.03
# i_vsrc_A2_n_r =  0.01
# i_vsrc_A2_a_i = -3.39
# i_vsrc_A2_b_i = 14.21
# i_vsrc_A2_c_i = -10.89
# i_vsrc_A2_n_i =  0.07
# i_vsc_A1_a_r = 14.37
# i_vsc_A1_b_r = -4.34
# i_vsc_A1_c_r = -10.03
# i_vsc_A1_n_r = -0.01
# v_A1_o_r =  0.00
# p_dc_A1 = 11394.94
# i_dc_A1 = 14.24
# i_vsc_A1_a_i =  3.39
# i_vsc_A1_b_i = -14.21
# i_vsc_A1_c_i = 10.89
# i_vsc_A1_n_i = -0.07
# v_A1_o_i = -0.00
# p_pos_A1 = 10000.00
# q_pos_A1 = -2303.58
# phi_a_A1 =  0.00
# phi_b_A1 = -2.09
# phi_c_A1 =  2.10
# m_a_A1 =  0.71
# m_b_A1 =  0.71
# m_c_A1 =  0.71
# omega_A1 =  1.00
# p_m_A1 =  0.10
# v_dc_A1 = 800.00
# v_fc_dc_A1 = 429.72
# omega_coi =  1.00
# p_agc =  0.00

# %%
model = temp.model()
model.Dt = 0.01
model.ini(params,xy_0='xy_0.json')
model.ini({'p_c_A1':0.1,'K_delta_A1':0.0})
model.run(1,{})
model.run(40,{"p_c_A1" :0.2})
model.post();

# %%
fig = make_subplots(rows=2, cols=1)

fig.add_trace(go.Scatter(x=model.Time, y=model.get_values('p_pos_A1'), mode='lines', name='p_pos_A1 '), row=1, col=1)
fig.add_trace(go.Scatter(x=model.Time, y=model.get_values('q_pos_A1'), mode='lines', name='q_pos_A1 '), row=1, col=1)

fig.add_trace(go.Scatter(x=model.Time, y=model.get_values('omega_A1'), mode='lines', name='omega_A1 '), row=2, col=1)

fig.update_layout(height=600, width=800, title_text="Side By Side Subplots")
fig.show()

# %%
fig = make_subplots(rows=2, cols=2)

fig.add_trace(go.Scatter(x=model.Time, y=model.get_values('v_fc_dc_A1'), mode='lines', name='v_fc_dc_A1'), row=1, col=1)
fig.add_trace(go.Scatter(x=model.Time, y=model.get_values('v_dc_A1'), mode='lines', name='v_dc_A1'), row=1, col=1)
fig.add_trace(go.Scatter(x=model.Time, y=model.get_values('q_h2_A1'), mode='lines', name='q_h2_A1 '), row=2, col=1)
fig.add_trace(go.Scatter(x=model.Time, y=model.get_values('p_h2_A1'), mode='lines', name='p_h2_A1 '), row=1, col=2)

fig.update_layout(height=600, width=800, title_text="Side By Side Subplots")
fig.show()

# %%
model.report_u()
model.report_x()
model.report_y()
model.report_z()
# Out:
# e_ao_m_A2 =230.94
# e_bo_m_A2 =230.94
# e_co_m_A2 =230.94
# e_no_m_A2 = 0.00
# phi_A2 = 0.00
# m_n_A1 = 0.00
# phi_A1 = 0.00
# phi_n_A1 = 0.00
# phi_a_r_A1 = 0.00
# phi_b_r_A1 = 0.00
# phi_c_r_A1 = 0.00
# omega_ref_A1 = 1.00
# p_c_A1 = 0.00
# q_ref_A1 = 0.00
# e_ao_m_A1 =230.94
# e_bo_m_A1 =230.94
# e_co_m_A1 =230.94
# e_no_m_A1 = 0.00
# v_ra_A1 = 0.00
# v_rb_A1 = 0.00
# v_rc_A1 = 0.00
# v_rn_A1 = 0.00
# v_dc_h_ref_A1 =800.00
# temperature_A1 =1273.00
# i_dc_ref_A1 =10.00
# di_dc_ref_A1 = 0.00
# u_freq = 0.00
# phi_v_A1 =  0.00
# xi_p_A1 =  0.00
# p_ef_A1 = -0.00
# p_cf_A1 =  0.00
# De_ao_m_A1 =  0.00
# De_bo_m_A1 =  0.00
# De_co_m_A1 =  0.00
# De_no_m_A1 =  0.00
# q_h2_A1 =  0.00
# p_h2_A1 =  0.01
# p_h2o_A1 =  0.08
# p_o2_A1 =  0.01
# Di_dc_ref_A1 =  0.00
# xi_freq = -0.00
# V_A1_0_r = 230.94
# V_A1_0_i =  0.00
# V_A1_1_r = -115.47
# V_A1_1_i = -200.00
# V_A1_2_r = -115.47
# V_A1_2_i = 200.00
# V_A1_3_r = -0.00
# V_A1_3_i = -0.00
# V_A2_0_r = 230.94
# V_A2_0_i = -0.00
# V_A2_1_r = -115.47
# V_A2_1_i = -200.00
# V_A2_2_r = -115.47
# V_A2_2_i = 200.00
# V_A2_3_r =  0.00
# V_A2_3_i =  0.00
# i_vsrc_A2_a_r =  0.00
# i_vsrc_A2_b_r = -0.00
# i_vsrc_A2_c_r =  0.00
# i_vsrc_A2_n_r = -0.00
# i_vsrc_A2_a_i = -0.00
# i_vsrc_A2_b_i =  0.00
# i_vsrc_A2_c_i =  0.00
# i_vsrc_A2_n_i =  0.00
# i_vsc_A1_a_r = -0.00
# i_vsc_A1_b_r =  0.00
# i_vsc_A1_c_r = -0.00
# i_vsc_A1_n_r =  0.00
# v_A1_o_r =  0.00
# p_dc_A1 = 1333.34
# i_dc_A1 =  1.67
# i_vsc_A1_a_i =  0.00
# i_vsc_A1_b_i = -0.00
# i_vsc_A1_c_i = -0.00
# i_vsc_A1_n_i = -0.00
# v_A1_o_i =  0.00
# p_pos_A1 = -0.00
# q_pos_A1 = -1.29
# phi_a_A1 =  0.00
# phi_b_A1 = -2.09
# phi_c_A1 =  2.09
# m_a_A1 =  0.71
# m_b_A1 =  0.71
# m_c_A1 =  0.71
# omega_A1 =  1.00
# p_m_A1 = -0.00
# v_dc_A1 = 800.00
# v_fc_dc_A1 = 420.12
# omega_coi =  1.00
# p_agc = -0.00
# i_l_A1_0_A2_0_r = -0.00
# i_l_A1_0_A2_0_i =  0.00
# i_l_A1_1_A2_1_r =  0.00
# i_l_A1_1_A2_1_i = -0.00
# i_l_A1_2_A2_2_r = -0.00
# i_l_A1_2_A2_2_i = -0.00
# i_l_A1_3_A2_3_r =  0.00
# i_l_A1_3_A2_3_i = -0.00
# i_vsrc_A2_a_m =  0.00
# i_vsrc_A2_b_m =  0.00
# i_vsrc_A2_c_m =  0.00
# i_vsrc_A2_n_m =  0.00
# p_A2  =  0.00
# q_A2  =  1.29
# i_vsc_A1_a_m =  0.00
# i_vsc_A1_b_m =  0.00
# i_vsc_A1_c_m =  0.00
# i_vsc_A1_n_m =  0.00
# p_A1_pos = -0.00
# p_A1_neg = -0.00
# p_A1_zer = -0.00
# m_a_A1 =  0.71
# m_b_A1 =  0.71
# m_c_A1 =  0.71
# m_n_A1 =  0.00
# phi_A1 =  0.00
# p_dc_A1 = 1333.34
# p_s_total_A1 = -0.00
# e_ao_m_A1 = 230.94
# e_bo_m_A1 = 230.94
# e_co_m_A1 = 230.94
# v_ra_A1 =  0.00
# v_rb_A1 =  0.00
# v_rc_A1 =  0.00
# p_c_A1 =  0.00
# omega_ref_A1 =  1.00
# phi_v_A1 =  0.00
# v_tao_m_A1 = 230.94
# v_tbo_m_A1 = 230.94
# v_tco_m_A1 = 230.94
# Z_b_A1 =  1.60
# i_l_A1 =  3.17
# p_h_A1 = 1333.34
# m_h_A1 =  0.53
# V_ernst_A1 = -109.40
# P_dc_A1 = 4201.24
# i_dc_A1 =  1.67
# xi_freq = -0.00
# u_freq =  0.00

# %%
model=temp.model()
model.Dt = 0.1
model.ini({'p_load_D2':430*50, 'i_dc_ref_D1':0.0, 'U_opt_D1':0.7},'xy_0.json')
model.run(50.0,{})
# model.run(20,{'p_load_D2':0.001e3})
# model.run(40,{'p_load_D2':0.002e3})
# model.run(200,{'p_load_D2':0.005e3})
model.run(200,{'p_load_D2':430*20})
model.run(400,{'p_load_D2':430*10})

model.run(800,{'p_load_D2':430*100})

model.post();
# Out:
# Input or parameter p_load_D2 not found.
# Input or parameter i_dc_ref_D1 not found.
# Input or parameter U_opt_D1 not found.
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[8], line 3
#       1 model=temp.model()
#       2 model.Dt = 0.1
# ----> 3 model.ini({'p_load_D2':430*50, 'i_dc_ref_D1':0.0, 'U_opt_D1':0.7},'xy_0.json')
#       4 model.run(50.0,{})
#       5 # model.run(20,{'p_load_D2':0.001e3})
#       6 # model.run(40,{'p_load_D2':0.002e3})
#       7 # model.run(200,{'p_load_D2':0.005e3})
#
# File c:\Users\jmmau\workspace\pydae\src\pydae\urisi\fcs\temp.py:496, in model.ini(self, up_dict, xy_0)
#     493 if type(xy_0) == float or type(xy_0) == int:
#     494     self.xy_0 = np.ones(self.N_x+self.N_y,dtype=np.float64)*xy_0
# --> 496 xy_ini,it = sstate(self.xy_0,self.u_ini,self.p,
#     497                    self.jac_ini,
#     498                    self.N_x,self.N_y,
#     499                    max_it=self.max_it,tol=self.itol)
#     501 if it < self.max_it-1:
#     503     self.xy_ini = xy_ini
#
# File c:\Users\jmmau\anaconda3\Lib\site-packages\numba\np\linalg.py:827, in _check_finite_matrix()
#     825 for v in np.nditer(a):
#     826     if not np.isfinite(v.item()):
# --> 827         raise np.linalg.LinAlgError(
#     828             "Array must not contain infs or NaNs.")
#
# LinAlgError: Array must not contain infs or NaNs.

# %%
fig,axes = plt.subplots(nrows=2,ncols=2)

axes[0,0].plot(model.Time,model.get_values('v_dc_D1'), label='v_dc_D1')
axes[1,0].plot(model.Time,model.get_values('i_dc_D1'), label='i_dc_D1')

axes[0,1].plot(model.Time,  model.get_values('p_h2_D1'),label='p_h2')
axes[0,1].plot(model.Time,  model.get_values('p_h2o_D1'),label='p_h2o')
axes[0,1].plot(model.Time,  model.get_values('p_o2_D1'),label='p_o2')

axes[1,1].plot(model.Time,  model.get_values('q_h2_D1'),label='q_h2_D1')

for ax in axes.flatten():
    ax.grid()
    ax.legend()
    ax.set_xlim(0,model.Time[-1])
axes[1,0].set_xlabel('Time (s)')
axes[1,1].set_xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %%
model.report_z()
# Out:
# i_l_D1_0_D2_0_r = 107.91
# i_l_D1_0_D2_0_i =  0.00
# i_l_D1_1_D2_1_r = -107.91
# i_l_D1_1_D2_1_i =  0.00
# m_h_D1 =  0.54
# i_l_D1 = 201.21
# p_h_D1 = 86331.52
# e_h_D1 = 800.00
# V_ernst_D1 = -72.24
# P_dc_D1 = 86331.52
# i_dc_D1 = 201.21
# xi_freq =  0.00
# u_freq =  0.00
