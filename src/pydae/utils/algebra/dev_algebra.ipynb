# %%
2+2
# Out:
# 4

# %%
import pendulum
import numpy as np
model = pendulum.model()


M = 30.0  # mass of the bob (kg)
L = 5.21  # length of the pendulum (m)

model.ini({'M':M,'L':L,           # parameters setting
        'theta':np.deg2rad(0)  # initial desired angle = 0º
        },-1)                  # here -1 means that -1 is considered as initial gess for
                                # dynamic and algebraic states

model.report_x()  # obtained dynamic states
model.report_y()  # obtained algebraic states
model.report_z()  # obtained outputs
model.report_u()  # obtained algebraic states (theta is both state and output; f_x is both input and output)
model.report_params()  # considered parameters
# Out:
# p_x   =  0.00
# p_y   = -5.21
# v_x   =  0.00
# v_y   =  0.00
# lam   = 28.24
# theta =  0.00
# E_p   = -0.00
# E_k   =  0.00
# f_x   = -0.00
# f_x   =-0.00
# L     = 5.21
# G     = 9.81
# M     =30.00
# K_d   = 0.00

# %%
xy_0_dict = {
    "p_x": 1.943753270464573e-27,
    "p_y": 0,
    "v_x": 0.0,
    "v_y": 0.0,
    "lam": 0,
    "f_x": -1.0210510686201435e-24
}

model.ini({'M':M,'L':L,           # parameters setting
        'theta':np.deg2rad(0)  # initial desired angle = 0º
        },xy_0_dict)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[3], line 10
#       1 xy_0_dict = {
#       2     "p_x": 1.943753270464573e-27,
#       3     "p_y": 0,
#    (...)      7     "f_x": -1.0210510686201435e-24
#       8 }
# ---> 10 model.ini({'M':M,'L':L,           # parameters setting
#      11         'theta':np.deg2rad(0)  # initial desired angle = 0º
#      12         },xy_0_dict)
#
# File c:\Users\jmmau\workspace\pydae\src\pydae\utils\algebra\pendulum.py:501, in model.ini(self, up_dict, xy_0)
#     498 if type(xy_0) == float or type(xy_0) == int:
#     499     self.xy_0 = np.ones(self.N_x+self.N_y,dtype=np.float64)*xy_0
# --> 501 xy_ini,it = sstate(self.xy_0,self.u_ini,self.p,
#     502                    self.jac_ini,
#     503                    self.N_x,self.N_y,
#     504                    max_it=self.max_it,tol=self.itol)
#     506 if it < self.max_it-1:
#     508     self.xy_ini = xy_ini
#
# File c:\Users\jmmau\miniconda3\Lib\site-packages\numba\np\linalg.py:913, in _inv_err_handler()
#     911     assert 0   # unreachable
#     912 if r > 0:
# --> 913     raise np.linalg.LinAlgError(
#     914         "Matrix is singular to machine precision.")
#
# LinAlgError: Matrix is singular to machine precision.

# %%
xy_0_dict = {
    "p_x": 0.0,
    "p_y": 0.0,
    "v_x": 0.0,
    "v_y": 0.0,
    "lam": 0.0,
    "f_x": 0.0
}

model.dict2xy0(xy_0_dict)
model.jac_ini_eval()
model.jac_ini
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00, -3.33333333e-05,
#          0.00000000e+00, -0.00000000e+00,  3.33333333e-02],
#        [ 0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -3.33333333e-05, -0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -1.00000000e-06,  0.00000000e+00],
#        [            nan,             nan,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
model.save_xy_0('xy_0.json')
