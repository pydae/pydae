# %%
import numpy as np
import matplotlib.pyplot as plt
from pydae.bmapu import bmapu_builder

# %%
import temp

model = temp.model()
model.Dt = 1.0
model.decimation = 1

model.ini({'A_loss_1':0.0,'R_bat_1':0.02,'soc_ref_1':1.0, 'soc_min_1':0.01 },'xy_0.json')
model.run(2.0*3600,{'p_s_ref_1':0.5}) # half an hour discharging
model.run(4.0*3600,{'p_s_ref_1':-0.95}) # half an hour discharging
model.post()

# %%
fig,axes = plt.subplots(nrows=2,ncols=2)
axes[0,0].plot(model.Time, model.get_values('p_dc_1'))
axes[1,0].plot(model.Time, model.get_values('soc_1'))
axes[0,1].plot(model.Time, model.get_values('v_dc_1'))
axes[0,1].plot(model.Time, model.get_values('e_1'))
axes[1,1].plot(model.Time, model.get_values('i_dc_1'))

for ax in axes.flatten():
    ax.grid()

# axes[1,0].set_ylim(0.009,0.011)

# %%
model.get_value('K_p_1')
# Out:
# 1e-06

# %%
model = temp.model()
model.Dt = 1.0
model.decimation = 1

model.ini({'A_loss_1':0.0,'R_bat_1':0.1},'xy_0.json')
model.run(1.5*3600,{'p_s_ref_1':1.0}) # an hour discharging
model.post()

# %%
fig,axes = plt.subplots(nrows=2,ncols=2)
axes[0,0].plot(model.Time, model.get_values('p_dc_1'))
axes[1,0].plot(model.Time, model.get_values('sigma_1'))
axes[0,1].plot(model.Time, model.get_values('v_dc_1'))
axes[1,1].plot(model.Time, model.get_values('i_dc_1'))

for ax in axes.flatten():
    ax.grid()

axes[1,0].set_ylim(-0.001,0.001)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\jmmau\workspace\pydae\src\pydae\bmapu\vscs\bess_pq.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/jmmau/workspace/pydae/src/pydae/bmapu/vscs/bess_pq.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> fig,axes = plt.subplots(nrows=2,ncols=2)
#       <a href='vscode-notebook-cell:/c%3A/Users/jmmau/workspace/pydae/src/pydae/bmapu/vscs/bess_pq.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> axes[0,0].plot(model.Time, model.get_values('p_dc_1'))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jmmau/workspace/pydae/src/pydae/bmapu/vscs/bess_pq.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> axes[1,0].plot(model.Time, model.get_values('sigma_1'))
#       <a href='vscode-notebook-cell:/c%3A/Users/jmmau/workspace/pydae/src/pydae/bmapu/vscs/bess_pq.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> axes[0,1].plot(model.Time, model.get_values('v_dc_1'))
#       <a href='vscode-notebook-cell:/c%3A/Users/jmmau/workspace/pydae/src/pydae/bmapu/vscs/bess_pq.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> axes[1,1].plot(model.Time, model.get_values('i_dc_1'))
#
# File c:\Users\jmmau\workspace\pydae\src\pydae\bmapu\vscs\temp.py:388, in model.get_values(self, name)
#     385 if name in self.outputs_list:
#     386     values = self.Z[:,self.outputs_list.index(name)]
# --> 388 return values
#
# UnboundLocalError: local variable 'values' referenced before assignment

# %%
model.report_params()
# Out:
# S_base =100000000.00
# U_1_n =20000.00
# K_p_1 = 0.00
# K_i_1 = 0.00
# soc_min_1 = 0.00
# soc_max_1 = 1.00
# S_n_1 =10000000.00
# E_kWh_1 =20000.00
# A_loss_1 = 0.00
# B_loss_1 = 0.00
# C_loss_1 = 0.00
# R_bat_1 =10.00
# K_p_agc = 0.00
# K_i_agc = 0.00
# K_xif = 0.00

# %%
np.array([600, 650, 680, 700,710,750])/600
# Out:
# array([1.        , 1.08333333, 1.13333333, 1.16666667, 1.18333333,
#        1.25      ])
