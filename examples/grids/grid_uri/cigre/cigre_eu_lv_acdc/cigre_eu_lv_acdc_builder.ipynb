# %%
import numpy as np
import matplotlib.pyplot as plt
#from pydgrid.plot_bokeh import plot_results
import sympy as sym
import pydae.build as db
import pydae.build_cffi as db

from pydae.grid_urisi import unb_ri_si
import json
import networkx as nx
import time

# %%
grid = unb_ri_si('cigre_eu_lv_acdc.json')

# %%
with open('cigre_eu_lv_acdc.json','r') as fobj:
    data = json.loads(fobj.read().replace("'",'"'))
    
G = nx.Graph()

for bus in data['buses']:
    G.add_node(bus['bus'])  # default edge data=1
    
for line in data['lines']:
    G.add_edge(line['bus_j'], line['bus_k'],color='r',weight=10)  # default edge data=1
for trafo in data['transformers']:
    G.add_edge(trafo['bus_j'], trafo['bus_k'],color='g')  # default edge data=1
for vsc in data['vscs']:
    G.add_edge(vsc['bus_ac'], vsc['bus_dc'],color='b')  # default edge data=1
        
colors = nx.get_edge_attributes(G,'color').values()
        
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 10),sharex=True)

nx.draw(G,pos=nx.spring_layout(G),node_size=200, edge_color=colors,with_labels=True)   # default spring_layout
#subax2 = plt.subplot(122)
#nx.draw(G, pos=nx.circular_layout(G), node_color='r', edge_color='b')

# %%
nx.is_connected(G)
colors = nx.get_edge_attributes(G,'color').values()
colors
# Out:
# dict_values(['g', 'g', 'g', 'r', 'b', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'b', 'r', 'r', 'r', 'b', 'r', 'b', 'b', 'r', 'b', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'b', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'b', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r'])

# %%
params_dict  = grid.dae['params']
f_list = grid.dae['f']
x_list = grid.dae['x']
g_list = grid.dae['g'] 
y_list = grid.dae['y'] 
u_dict = grid.dae['u']


h_dict = grid.dae['h_dict']
h_dict.update(grid.dae['h_v_m_dict'])

sys_dict = {'name':'cigre_eu_lv_acdc',
           'params_dict':params_dict,
           'f_list':f_list,
           'g_list':g_list,
           'x_list':x_list,
           'y_ini_list':y_list,
           'y_run_list':y_list,
           'u_run_dict':u_dict,
           'u_ini_dict':u_dict,
           'h_dict':h_dict
           }

db.build(sys_dict,verbose=True);
# Out:
# check_system (time: 0.0)
# system without dynamic equations, adding dummy dynamic equation
# computing jacobians Fx_run,Fy_run  (time: 0.935 s)
# computing jacobians Gx_run,Gy_run  (time: 0.999 s)
# computing jacobians Fu_run,Gu_run  (time: 41.502 s)
# computing jacobians Fx_ini,Fy_ini  (time: 60.350 s)
# computing jacobians Gx_ini,Gy_ini  (time: 60.410 s)
# computing jacobians Hx_run,Hy_run,Hu_run  (time: 99.12241291999817 s)
# end system  (time: 151.542 s)
# computing jac_ini (time: 0.0)
# computing jac_run (time: 0.8469703197479248)
# computing jac_trap (time: 1.6412873268127441)
# end of jacobians computation (time: 2.467)
# writting f_ini and g_ini code (time: 0.000 s)
# writting f_run and g_run code (time: 33.666 s)
# writting h_run code (time: 65.267 s)
# converting jac_ini to sp_jac_ini  (time: 84.813 s)
# running sym2rhs for sp_jac_ini (time: 85.174 s)
# converting jac_run to sp_jac_run  (time: 103.993 s)
# running sym2rhs for sp_jac_run (time: 104.125 s)
# converting jac_trap to sp_jac_trap  (time: 122.542 s)
# running sym2rhs for sp_jac_trap (time: 122.683 s)
# wrtting  de_jac_trap code (time: 140.371 s)
# writting sp_jac_trap code (time: 140.402 s)
# writting full source (time: 140.417 s)
# Code wrote in 140.433 s
# Compilation time: 58.62 s
# sys2num (time: 0.110)

# %%
N_y = len(sys_dict['g'])
G_y = sym.zeros(N_y)
t_0 = time.time()

for irow in range(N_y):
    str_g =  str(sys_dict['g'][irow])
    for icol in range(N_y):
        if str(sys_dict['y_ini'][icol]) in str_g:
            G_y[irow,icol] = sys_dict['g'][irow].diff(sys_dict['y_ini'][icol]);
print(time.time() - t_0)
# Out:
# 56.493080615997314

# %% [raw]
# # windows i7
# check_system (time: 0.0)
# system without dynamic equations, adding dummy dynamic equation
# computing jacobians Fx_run,Fy_run  (time: 0.339 s)
# computing jacobians Gx_run,Gy_run  (time: 0.376 s)
# computing jacobians Fu_run,Gu_run  (time: 115.520 s)
# computing jacobians Fx_ini,Fy_ini  (time: 189.861 s)
# computing jacobians Gx_ini,Gy_ini  (time: 189.912 s)
# computing jacobians Hx_run,Hy_run,Hu_run  (time: 314.98264479637146 s)
# end system  (time: 460.569 s)
# computing jac_ini (time: 0.0)
# computing jac_run (time: 0.6745965480804443)
# computing jac_trap (time: 1.3401875495910645)
# end of jacobians computation (time: 2.022)
# writting f_ini and g_ini code (time: 0.000 s)
# writting f_run and g_run code (time: 28.856 s)
# writting h_run code (time: 58.151 s)
# converting jac_ini to sp_jac_ini  (time: 77.571 s)
# running sym2rhs for sp_jac_ini (time: 77.728 s)
# converting jac_run to sp_jac_run  (time: 95.010 s)
# running sym2rhs for sp_jac_run (time: 95.129 s)
# converting jac_trap to sp_jac_trap  (time: 110.401 s)
# running sym2rhs for sp_jac_trap (time: 110.532 s)
# wrtting  de_jac_trap code (time: 125.557 s)
# writting sp_jac_trap code (time: 125.573 s)
# writting full source (time: 125.589 s)
# Code wrote in 125.589 s
# Compilation time: 608.48 s
# sys2num (time: 0.571)

# %% [raw]
# colab:
# check_system (time: 1.430511474609375e-06)
# system without dynamic equations, adding dummy dynamic equation
# computing jacobians Fx_run,Fy_run  (time: 0.405 s)
# computing jacobians Gx_run,Gy_run  (time: 0.445 s)
# computing jacobians Fu_run,Gu_run  (time: 81.201 s)
# computing jacobians Fx_ini,Fy_ini  (time: 125.783 s)
# computing jacobians Gx_ini,Gy_ini  (time: 125.826 s)
# computing jacobians Hx_run,Hy_run,Hu_run  (time: 206.30300664901733 s)
# end system  (time: 306.385 s)
# computing jac_ini (time: 3.337860107421875e-06)
# computing jac_run (time: 6.011882066726685)
# computing jac_trap (time: 12.334789276123047)
# end of jacobians computation (time: 19.508)
# writting f_ini and g_ini code (time: 0.000 s)
# writting f_run and g_run code (time: 19.179 s)
# writting h_run code (time: 37.945 s)
# converting jac_ini to sp_jac_ini  (time: 50.011 s)
# running sym2rhs for sp_jac_ini (time: 53.550 s)
# converting jac_run to sp_jac_run  (time: 63.437 s)
# running sym2rhs for sp_jac_run (time: 67.259 s)
# converting jac_trap to sp_jac_trap  (time: 77.032 s)
# running sym2rhs for sp_jac_trap (time: 80.612 s)
# wrtting  de_jac_trap code (time: 90.490 s)
# writting sp_jac_trap code (time: 90.498 s)
# writting full source (time: 90.506 s)
# Code wrote in 90.509 s
# Compilation time: 105.58 s
# sys2num (time: 0.038)

# %% [markdown]
# ## Experimental initial conditions

# %%
delta = np.deg2rad(30)
for item in grid.dae['xy_0_dict']:
    ph = item.split('_')[2]
    ir = item.split('_')[3]
    if ph == 'a':
        v = 400.0/np.sqrt(3)*np.exp(1j*0.0+delta)
        if ir == 'r':
            grid.dae['xy_0_dict'][item] = v.real
        if ir == 'i':
            grid.dae['xy_0_dict'][item] = v.imag
    if ph == 'b':
        v = 400.0/np.sqrt(3)*np.exp(1j*(-2/3*np.pi+delta))
        if ir == 'r':
            grid.dae['xy_0_dict'][item] = v.real
        if ir == 'i':
            grid.dae['xy_0_dict'][item] = v.imag  
    if ph == 'c':
        v = 400.0/np.sqrt(3)*np.exp(1j*(-4/3*np.pi+delta))
        if ir == 'r':
            grid.dae['xy_0_dict'][item] = v.real
        if ir == 'i':
            grid.dae['xy_0_dict'][item] = v.imag 

data = json.dumps(grid.dae['xy_0_dict'], indent=4)
fobj = open("xy_0_dict.json","w")
fobj.write(data)
fobj.close()

# %%
grid.dae['xy_0_dict']

# %%
import pydgrid

# %%
grid = pydgrid.grid()
grid.read('cigre_eu_lv.json')
grid.pf()
grid.buses

# %%
grid = unb_ri_si('cigre_eu_lv_reduced.json')

params_dict  = grid.dae['params']
f_list = grid.dae['f']
x_list = grid.dae['x']
g_list = grid.dae['g'] 
y_list = grid.dae['y'] 
u_dict = grid.dae['u']


h_dict = grid.dae['h_dict']
h_dict.update(grid.dae['h_v_m_dict'])

sys_dict = {'name':'cigre_eu_lv_reduced',
           'params_dict':params_dict,
           'f_list':f_list,
           'g_list':g_list,
           'x_list':x_list,
           'y_ini_list':y_list,
           'y_run_list':y_list,
           'u_run_dict':u_dict,
           'u_ini_dict':u_dict,
           'h_dict':h_dict
           }

db.build(sys_dict,verbose=True)

# %%
with open('cigre_eu_lv_acdc.json','r') as fobj:
    data = json.loads(fobj.read().replace("'",'"'))

# %%
data

# %%
from networkx.algorithms.dag import transitive_closure

def dependency_graph(G, nodes):
    return transitive_closure(G).subgraph(nodes)

G = nx.Graph() 
G.add_edges_from([(1,3),(3,4),(1,5),(5,6),(2,6),(4,6)])

print(dependency_graph(G, [1, 2, 4, 6]).edges)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_65264/3851732968.py in <module>
#       7 G.add_edges_from([(1,3),(3,4),(1,5),(5,6),(2,6),(4,6)])
#       8
# ----> 9 print(dependency_graph(G, [1, 2, 4, 6]).edges)
#
# ~\AppData\Local\Temp/ipykernel_65264/3851732968.py in dependency_graph(G, nodes)
#       2
#       3 def dependency_graph(G, nodes):
# ----> 4     return transitive_closure(G).subgraph(nodes)
#       5
#       6 G = nx.Graph()
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in argmap_transitive_closure_13(G, reflexive)
#       1 from collections import defaultdict
#       2 from os.path import splitext
# ----> 3 from contextlib import contextmanager
#       4 from pathlib import Path
#       5 import warnings
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _not_implemented_for(g)
#      85             dval is None or dval == g.is_directed()
#      86         ):
# ---> 87             raise nx.NetworkXNotImplemented(errmsg)
#      88
#      89         return g
#
# NetworkXNotImplemented: not implemented for undirected type

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph() 
G.add_edges_from([(1,3),(3,4),(1,5),(5,6),(2,6),(4,6)])

threshold = 2
#G_s  = G.subgraph([node for node in G.nodes() if G.degree(node) != threshold])

G_s, c_nodes = nx.dedensify(G, threshold=threshold)

fig, ax = plt.subplots(2, 1)

nx.draw(  G, ax = ax[0], with_labels = 1)
nx.draw(G_s, ax = ax[1], with_labels = 1)

# %%
nodes = {
    "A": dict(color="Red"),
    "B": dict(color="Red"),
    "C": dict(color="Red"),
    "D": dict(color="Red"),
    "E": dict(color="Blue"),
    "F": dict(color="Blue"),
}
edges = [
    ("A", "E", "Strong"),
    ("B", "F", "Strong"),
    ("C", "E", "Weak"),
    ("D", "F", "Weak"),
]
G = nx.Graph()
for node in nodes:
    attributes = nodes[node]
    G.add_node(node, **attributes)

for source, target, type in edges:
    G.add_edge(source, target, type=type)

node_attributes = ('color', )
edge_attributes = ('type', )
G_s = nx.snap_aggregation(G, node_attributes=node_attributes, edge_attributes=edge_attributes)

fig, ax = plt.subplots(2, 1)

nx.draw(  G, ax = ax[0], with_labels = 1)
nx.draw(G_s, ax = ax[1], with_labels = 1)

# %%
G_s.edges.data()
# Out:
# EdgeDataView([('Supernode-0', 'Supernode-1', {'types': [{'type': 'Strong'}]}), ('Supernode-1', 'Supernode-2', {'types': [{'type': 'Weak'}]})])

# %%
l = [('1','2'),('2','3'),('3','4'),('3','5'),('1','6'),('6','7'),('6','8'),('9','8')]

G=nx.Graph()

G.add_edges_from(l)
G_s = G.copy()


# Select all nodes with only 2 neighbors
nodes_to_remove = [n for n in G.nodes if len(list(G.neighbors(n))) == 2]

# For each of those nodes
for node in nodes_to_remove:
    # We add an edge between neighbors (len == 2 so it is correct)
    G_s.add_edge(*G_s.neighbors(node))
    # And delete the node
    G_s.remove_node(node)

fig, ax = plt.subplots(2, 1)

nx.draw(G,ax = ax[0],with_labels=True)
nx.draw(G_s,ax = ax[1],with_labels=True)
